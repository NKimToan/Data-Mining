# %%
import pandas as pd
from apyori import apriori

# %%
df= pd.read_csv("basket_apriori.csv")
df
# Out:
#       ID  Apple  Bread  Butter  Cheese  Corn  Dill  Eggs  Ice cream  \
# 0      1    NaN    1.0     NaN     NaN   1.0   1.0   NaN        1.0
# 1      2    NaN    NaN     NaN     NaN   NaN   NaN   NaN        NaN
# 2      3    1.0    NaN     1.0     NaN   NaN   1.0   NaN        1.0
# 3      4    NaN    NaN     1.0     1.0   NaN   1.0   NaN        NaN
# 4      5    1.0    1.0     NaN     NaN   NaN   NaN   NaN        NaN
# ..   ...    ...    ...     ...     ...   ...   ...   ...        ...
# 994  995    NaN    1.0     NaN     NaN   NaN   NaN   1.0        NaN
# 995  996    1.0    NaN     NaN     NaN   1.0   NaN   NaN        NaN
# 996  997    1.0    NaN     NaN     NaN   1.0   1.0   NaN        NaN
# 997  998    NaN    NaN     1.0     1.0   1.0   NaN   1.0        1.0
# 998  999    NaN    NaN     NaN     NaN   NaN   NaN   NaN        NaN
#
#      Kidney Beans  Milk  Nutmeg  Onion  Sugar  Unicorn  Yogurt  chocolate
# 0             NaN   NaN     NaN    NaN    1.0      NaN     1.0        1.0
# ...

# %%
df.shape
# Out:
# (999, 17)

# %%
records = []
for i in range (999):
    records.append([str(df.values[i,j]) for j in range(17)])
records
# Out:
# [['1.0',
#   'nan',
#   '1.0',
#   'nan',
#   'nan',
#   '1.0',
#   '1.0',
#   'nan',
#   '1.0',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   '1.0',
#   'nan',
#   '1.0',
#   '1.0'],
#  ['2.0',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   '1.0',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['3.0',
#   '1.0',
#   'nan',
#   '1.0',
#   'nan',
#   'nan',
#   '1.0',
#   'nan',
#   '1.0',
#   'nan',
#   '1.0',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   '1.0',
#   '1.0'],
#  ['4.0',
#   'nan',
#   'nan',
#   '1.0',
#   '1.0',
#   'nan',
#   '1.0',
#   'nan',
#   'nan',
#   'nan',
#   '1.0',
#   '1.0',
#   '1.0',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['5.0',
#   '1.0',
#   '1.0',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['6.0',
#   '1.0',
#   '1.0',
#   '1.0',
#   '1.0',
# ...

# %%
asscociation_rules = apriori(records, min_support=0.10, min_confidence = 0.1, min_lift = 1.2, min_length = 1)
asscociation_rules = list(asscociation_rules)
print(asscociation_rules)
# Out:
# []
